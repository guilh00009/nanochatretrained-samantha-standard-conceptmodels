# %%
# !git clone https://github.com/guilh00009/nanochatretrained-samantha-standard-conceptmodels.git
# Out:
# Cloning into 'nanochatretrained-samantha-standard-conceptmodels'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 13 (delta 2), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (13/13), 34.91 KiB | 6.98 MiB/s, done.
# Resolving deltas: 100% (2/2), done.

# %%
# %cd nanochatretrained-samantha-standard-conceptmodels/
# Out:
# /content/nanochatretrained-samantha-standard-conceptmodels

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121, https://pypi.org/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.5/16.5 MB 89.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 564.3/564.3 kB 46.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.8/56.8 MB 18.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: huggingface_hub
#     Found existing installation: huggingface-hub 0.36.0
#     Uninstalling huggingface-hub-0.36.0:
#       Successfully uninstalled huggingface-hub-0.36.0
# ...

# %%
from huggingface_hub import hf_hub_download
from pathlib import Path
import shutil

repo_id = "Guilherme34/nanochat-retrained-pytorch-duplicated"
files = [
    "model_000700.pt",
    "meta_000700.json",
    "token_bytes.pt",
    "tokenizer.pkl",
]

# Output directory
out_dir = Path("/content/nanochatretrained-samantha-standard-conceptmodels/model")
out_dir.mkdir(parents=True, exist_ok=True)

downloaded = []
for fname in files:
    cached_path = hf_hub_download(
        repo_id=repo_id,
        filename=fname,
        revision="main"
    )
    target = out_dir / fname
    shutil.copy2(cached_path, target)
    downloaded.append(str(target))

print("✅ Saved files to:", out_dir)
print("\n".join(downloaded))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# model_000700.pt:   0%|          | 0.00/7.25G [00:00<?, ?B/s]
# meta_000700.json:   0%|          | 0.00/244 [00:00<?, ?B/s]
# token_bytes.pt:   0%|          | 0.00/264k [00:00<?, ?B/s]
# tokenizer.pkl:   0%|          | 0.00/846k [00:00<?, ?B/s]
# ✅ Saved files to: /content/nanochatretrained-samantha-standard-conceptmodels/model
# /content/nanochatretrained-samantha-standard-conceptmodels/model/model_000700.pt
# ...

# %%
# !wget https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb && sudo dpkg -i cloudflared-linux-amd64.deb
# Out:
# --2025-11-12 15:58:43--  https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/cloudflare/cloudflared/releases/download/2025.11.1/cloudflared-linux-amd64.deb [following]
# --2025-11-12 15:58:43--  https://github.com/cloudflare/cloudflared/releases/download/2025.11.1/cloudflared-linux-amd64.deb
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cd nanochatretrained-samantha-standard-conceptmodels/
# !python concept_lab_app.py
# Out:
# [Errno 2] No such file or directory: 'nanochatretrained-samantha-standard-conceptmodels/'
# /content/nanochatretrained-samantha-standard-conceptmodels
# Launching Nanochat Concept Lab on http://localhost:7861 ...
# * Running on local URL:  http://0.0.0.0:7861
# * Running on public URL: https://79dd9c2ecfbbd3ef0d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Using 1 GPU(s) out of 1 available
# Detecting model dtype from /content/nanochatretrained-samantha-standard-conceptmodels/model/model_000700.pt...
# Model original dtype: torch.bfloat16
# Building model architecture on meta device...
# Loading weights from disk...
# Loading to single GPU (cuda:0)...
# Model loaded successfully on single GPU
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
# ...
